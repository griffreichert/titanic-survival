# %%
# Import standard ibraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import os
import re
from pathlib import Path

# Data processing
from category_encoders import *

# Modelling
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

sns.set_theme()

# %% [markdown]
# ## 1. Download & Load Data

# %%
DATA_PATH = Path('./data')

if 'data' not in os.listdir('..') or 'train.csv' not in os.listdir('../data'):
    print('downloading kaggle data')
    ! mkdir ./data
    ! kaggle competitions download -c titanic
    ! unzip titanic.zip
    ! mv *.csv ./data
    ! rm titanic.zip
    ! mkdir ./data/submissions
    ! mv ./data/*_submission* ./data/submissions/
else:
    print('kaggle data already downloaded in ../data')
# Out:
# downloading kaggle data
# mkdir: ./data: File exists
# zsh:1: command not found: kaggle
# unzip:  cannot find or open titanic.zip, titanic.zip.zip or titanic.zip.ZIP.
# zsh:1: no matches found: *.csv
# rm: titanic.zip: No such file or directory
# mkdir: ./data/submissions: File exists
# zsh:1: no matches found: ./data/*_submission*

# %%
train = pd.read_csv(DATA_PATH / 'train.csv', index_col=0)
test = pd.read_csv(DATA_PATH / 'test.csv', index_col=0)

low_func = lambda x: x.lower()

train.columns = map(low_func, train.columns)
test.columns = map(low_func, test.columns)

print('train', train.shape)
print('test', test.shape)
# Out:
# train (891, 11)
# test (418, 10)

# %% [markdown]
# **variable exploration**
#
# pclass: A proxy for socio-economic status (SES)
# - 1st = Upper
# - 2nd = Middle
# - 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# ## 2. Data Analysis & Cleansing

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    418 non-null    int64
#  1   name      418 non-null    object
#  2   sex       418 non-null    object
#  3   age       332 non-null    float64
#  4   sibsp     418 non-null    int64
#  5   parch     418 non-null    int64
#  6   ticket    418 non-null    object
#  7   fare      417 non-null    float64
#  8   cabin     91 non-null     object
#  9   embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %% [markdown]
# Immediately we see that cabin is a sparse column that has a lot of nulls.
#
# Age, Embarked & Fare also have null values to deal with

# %%
train.head()
# Out:
#              survived  pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           name     sex   age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              sibsp  parch            ticket     fare cabin embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train.cabin.value_counts()[:20].plot.bar()
# Out:
# <AxesSubplot: >

# %%
train.groupby('embarked').survived.mean()
# Out:
# embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: survived, dtype: float64

# %%
sns.histplot(train, x='embarked', hue='survived', multiple='dodge')
# Out:
# <AxesSubplot: xlabel='embarked', ylabel='Count'>

# %%
# most people embarked in Southampton so fill na values with an S (the modal value)
# interesting to note that a higher ratio of passengers from C survived

train_embarked_mode = train[~pd.isna(train.embarked)].embarked.mode()[0]

train['embarked'] = train.embarked.fillna(train_embarked_mode)
test['embarked'] = test.embarked.fillna(train_embarked_mode)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
g = sns.FacetGrid(train, col='survived')
g.map(plt.hist, 'age', bins=20)

# %%
sns.histplot(train, x='age', hue='survived', multiple='stack')
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
print('Survival rates')
print(f'mean: {train.survived.mean():.2f}')
print(f'u8: {train[train.age < 8].survived.mean():.2f}')
# Out:
# Survival rates
# mean: 0.38
# u8: 0.68

# %% [markdown]
# It appears that children below 8 had a high survival rate, so age will be a strong factor

# %% [markdown]
# ### Investigate Relationship between Gender and Survival

# %%
train.groupby('sex').survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
sns.histplot(train, x='age', hue='sex', multiple='stack')
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
g = sns.histplot(train, x='survived', hue='sex', multiple='dodge', stat='percent')
plt.show()

# %%
train.name.value_counts()
# Out:
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: name, Length: 891, dtype: int64

# %% [markdown]
# Names are unique (count=891)

# %% [markdown]
# ### Investigate Passenger Class

# %%
sns.histplot(train, x='age', hue='pclass', multiple='stack')
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
train.groupby('pclass').age.mean()
# Out:
# pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: age, dtype: float64

# %%
train.groupby('pclass').survived.mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %% [markdown]
# Passengers in first class were on average older

# %%
sns.catplot(train, x='pclass', y='fare', hue='survived')

# %%
sns.regplot(train, x='age', y='fare', x_bins=20)
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
sns.regplot(train, x='pclass', y='fare', x_bins=20)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
grid = sns.FacetGrid(train, col='survived', row='pclass', height=2.2, aspect=1.6)
grid.map(plt.hist, 'age', bins=20)
grid.add_legend();

# %%
grid = sns.FacetGrid(train, col='survived', row='embarked', height=2.2, aspect=1.6)
grid.map(plt.hist, 'age')
grid.add_legend();

# %% [markdown]
# ### Investigate Family Size

# %%
train.groupby('sibsp').survived.mean()
# Out:
# sibsp
# 0    0.345395
# 1    0.535885
# 2    0.464286
# 3    0.250000
# 4    0.166667
# 5    0.000000
# 8    0.000000
# Name: survived, dtype: float64

# %%
sns.histplot(train, x='sibsp', hue='survived', multiple='stack', discrete=True)
plt.show()
train.groupby('sibsp').survived.mean()
# Out:
# sibsp
# 0    0.345395
# 1    0.535885
# 2    0.464286
# 3    0.250000
# 4    0.166667
# 5    0.000000
# 8    0.000000
# Name: survived, dtype: float64

# %%
sns.histplot(train, x='parch', hue='survived', multiple='stack', discrete=True)
plt.show()
train.groupby('parch').survived.mean()
# Out:
# parch
# 0    0.343658
# 1    0.550847
# 2    0.500000
# 3    0.600000
# 4    0.000000
# 5    0.200000
# 6    0.000000
# Name: survived, dtype: float64

# %% [markdown]
#
# ### Fill in missing values for age and fare

# %%
median_age_by_sex_pclass = train[~pd.isna(train.age)].groupby(['sex', 'pclass']).age.median().rename('median_age')
median_age_by_sex_pclass
# Out:
# sex     pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: median_age, dtype: float64

# %%
# fill in NA ages with the median age of people with the same sex and pclass 
#   - Sex & pclass used due to low dimensionality and correlation with age
train['age'] = (
    train['age'].fillna(
        train.merge(median_age_by_sex_pclass, how='left', 
                    left_on=['sex', 'pclass'], right_index=True)['median_age']
    )
)
test['age'] = (
    test['age'].fillna(
        test.merge(median_age_by_sex_pclass, how='left', 
                    left_on=['sex', 'pclass'], right_index=True)['median_age']
    )
)

# %%
assert sum(pd.isna(test.age)) == 0 and sum(pd.isna(train.age)) == 0

# %%
median_fare_by_pclass = train[~pd.isna(train.fare)].groupby('pclass').fare.median().rename('median_fare')
median_fare_by_pclass
# Out:
# pclass
# 1    60.2875
# 2    14.2500
# 3     8.0500
# Name: median_fare, dtype: float64

# %%
# fill in NA fares with the median fare of people with the same pclass 

train['fare'] = (
    train['fare'].fillna(
        train.merge(median_fare_by_pclass, how='left', 
                    left_on='pclass', right_index=True)['median_fare']
    )
)
test['fare'] = (
    test['fare'].fillna(
        test.merge(median_fare_by_pclass, how='left', 
                    left_on='pclass', right_index=True)['median_fare']
    )
)

# %%
assert sum(pd.isna(test.fare)) == 0 and sum(pd.isna(train.fare)) == 0

# %% [markdown]
# ## 3. Feature Engineering

# %%
# drop the cabin and ticket columns as they are mostly noise
train = train.drop(columns=['cabin', 'ticket'])
test = test.drop(columns=['cabin', 'ticket'])

train.shape, test.shape
# Out:
# ((891, 9), (418, 8))

# %%
train.head()
# Out:
#              survived  pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           name     sex   age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              sibsp  parch     fare embarked
# PassengerId
# 1                1      0   7.2500        S
# 2                1      0  71.2833        C
# 3                0      0   7.9250        S
# 4                1      0  53.1000        S
# 5                0      0   8.0500        S

# %% [markdown]
# ### Convert categorical features to numeric

# %%
train.groupby('embarked').survived.mean()
# Out:
# embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: survived, dtype: float64

# %%
encoder = TargetEncoder()
train['embarked_target_encoded'] = encoder.fit_transform(train.embarked, train.survived)
test['embarked_target_encoded'] = encoder.transform(test.embarked)

# %%
embarked_categories = {
    'S': 0,
    'C': 1, 
    'Q': 2, 
}
train['embarked_ordinal_encoded'] = train.embarked.map(embarked_categories)
test['embarked_ordinal_encoded'] = test.embarked.map(embarked_categories)

# %%
train['sex_target_encoded'] = encoder.fit_transform(train.sex, train.survived)
test['sex_target_encoded'] = encoder.transform(test.sex)

# %%
gender_categories = {
    'male': 0, 
    'female': 1
}
train['sex_ordinal_encoded'] = train.sex.map(gender_categories)
test['sex_ordinal_encoded'] = test.sex.map(gender_categories)

# %%
train.head()
# Out:
#              survived  pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           name     sex   age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              sibsp  parch     fare embarked  embarked_target_encoded  \
# PassengerId
# 1                1      0   7.2500        S                 0.339009
# 2                1      0  71.2833        C                 0.553571
# 3                0      0   7.9250        S                 0.339009
# 4                1      0  53.1000        S                 0.339009
# 5                0      0   8.0500        S                 0.339009
#
#              embarked_ordinal_encoded  sex_target_encoded  sex_ordinal_encoded
# PassengerId
# 1                                   0            0.188908                    0
# 2                                   1            0.742038                    1
# 3                                   0            0.742038                    1
# 4                                   0            0.742038                    1
# 5                                   0            0.188908                    0

# %% [markdown]
# ### Create column 'title' from the name column

# %%
get_title = lambda x: re.findall(r"\w+\. ", x)[0].replace('. ', '').lower()
train['title'] = train.name.apply(get_title)
test['title'] = test.name.apply(get_title)

# %%
title_df = pd.merge(
    train['title'].value_counts(), 
    test['title'].value_counts(), 
    how='outer', 
    left_index=True, 
    right_index=True
).fillna(0).reset_index(level=0)
title_df = title_df.rename(columns={'index':'title'})
title_df['count'] = title_df['title_x'] + title_df['title_y']
title_df['count'] = title_df['count'].astype(int)
title_df = title_df.drop(columns=['title_x', 'title_y'])
title_df
# Out:
#        title  count
# 0       capt      1
# 1        col      4
# 2   countess      1
# 3        don      1
# 4       dona      1
# 5         dr      8
# 6   jonkheer      1
# 7       lady      1
# 8      major      2
# 9     master     61
# 10      miss    260
# 11      mlle      2
# 12       mme      1
# 13        mr    757
# 14       mrs    197
# 15        ms      2
# 16       rev      8
# 17       sir      1

# %%
title_map = {
    'mlle': 'miss',
    'major': 'misc',
    'col': 'misc',
    'countess': 'misc',
    'capt': 'misc',
    'ms': 'miss',
    'sir': 'mr',
    'lady': 'mrs',
    'mme': 'mrs',
    'don': 'mr',
    'dona': 'mrs',
    'jonkheer': 'misc',
}
train['title'] = train.title.map(title_map).fillna(train.title)
test['title'] = test.title.map(title_map).fillna(test.title)

# %%
title_df['title'] = title_df.title.map(title_map).fillna(title_df.title)
# title_df.groupby('title')['title'].value_counts()

# %%
train['title'].value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
test['title'].value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
train['title_target_encoded'] = encoder.fit_transform(train.title, train.survived)
test['title_target_encoded'] = encoder.transform(test.title)

# %%
title_ordinal = {
    'master': 1,
    'mr': 2,
    'rev': 3,
    'dr': 4,
    'mrs': 5,
    'miss': 6,
    'misc': 9,
}
train['title_ordinal_encoded'] = train.title.map(title_ordinal)
test['title_ordinal_encoded'] = test.title.map(title_ordinal)

# %%
# drop raw categorical features 
train = train.drop(columns=['name', 'sex', 'embarked', 'title'])
test = test.drop(columns=['name', 'sex', 'embarked', 'title'])
train.head()
# Out:
#              survived  pclass   age  sibsp  parch     fare  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500
# 2                   1       1  38.0      1      0  71.2833
# 3                   1       3  26.0      0      0   7.9250
# 4                   1       1  35.0      1      0  53.1000
# 5                   0       3  35.0      0      0   8.0500
#
#              embarked_target_encoded  embarked_ordinal_encoded  \
# PassengerId
# 1                           0.339009                         0
# 2                           0.553571                         1
# 3                           0.339009                         0
# 4                           0.339009                         0
# 5                           0.339009                         0
#
#              sex_target_encoded  sex_ordinal_encoded  title_target_encoded  \
# PassengerId
# 1                      0.188908                    0              0.157996
# 2                      0.742038                    1              0.795266
# 3                      0.742038                    1              0.702703
# 4                      0.742038                    1              0.795266
# 5                      0.188908                    0              0.157996
#
#              title_ordinal_encoded
# PassengerId
# 1                                2
# 2                                5
# 3                                6
# 4                                5
# 5                                2

# %%
""" 
Could do some age bands, family size, fare bands, etc

"""

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   survived                  891 non-null    int64
#  1   pclass                    891 non-null    int64
#  2   age                       891 non-null    float64
#  3   sibsp                     891 non-null    int64
#  4   parch                     891 non-null    int64
#  5   fare                      891 non-null    float64
#  6   embarked_target_encoded   891 non-null    float64
#  7   embarked_ordinal_encoded  891 non-null    int64
#  8   sex_target_encoded        891 non-null    float64
#  9   sex_ordinal_encoded       891 non-null    int64
#  10  title_target_encoded      891 non-null    float64
#  11  title_ordinal_encoded     891 non-null    int64
# dtypes: float64(5), int64(7)
# memory usage: 90.5 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pclass                    418 non-null    int64
#  1   age                       418 non-null    float64
#  2   sibsp                     418 non-null    int64
#  3   parch                     418 non-null    int64
#  4   fare                      418 non-null    float64
#  5   embarked_target_encoded   418 non-null    float64
#  6   embarked_ordinal_encoded  418 non-null    int64
#  7   sex_target_encoded        418 non-null    float64
#  8   sex_ordinal_encoded       418 non-null    int64
#  9   title_target_encoded      418 non-null    float64
#  10  title_ordinal_encoded     418 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 39.2 KB

# %% [markdown]
# ## Modelling Survival

# %%
# prepare data
# X_train =

# %% [markdown]
# ### Logistic Regression

# %%
logreg = LogisticRegression()
logreg.fit()
